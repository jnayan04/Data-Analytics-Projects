# %%
# Problem Statement:- 1.Analyse the factors behind increased cancellations of hotel room reservations.
#2.How can we decrease hotel reservation cancellations?
#3.How will hotels be assisted in making pricing and promotional decisions?

# %%
# Importing libraries:-

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings # to remove any possible warning
warnings.filterwarnings('ignore')# to ignore warnings

# %% [markdown]
# Loading the dataset:-

# %%
df=pd.read_csv("C:\\Users\\jroha\\Downloads\\hotel_bookings 2.csv")

# %% [markdown]
# Exploratory Data Analysis and data cleaning

# %%
df.head() # returning top 5 rows
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %%
df.tail() # returning last 5 rows
# Out:
#              hotel  is_canceled  lead_time  arrival_date_year  \
# 119385  City Hotel            0         23               2017
# 119386  City Hotel            0        102               2017
# 119387  City Hotel            0         34               2017
# 119388  City Hotel            0        109               2017
# 119389  City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 119385             August                        35
# 119386             August                        35
# 119387             August                        35
# 119388             August                        35
# 119389             August                        35
#
#         arrival_date_day_of_month  stays_in_weekend_nights  \
# 119385                         30                        2
# 119386                         31                        2
# 119387                         31                        2
# ...

# %%
df.shape # to get number of rows and columns
# Out:
# (119390, 32)

# %%
df.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
df.info() # to get data types
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
# we will analyse data based on reservation_status_date,hence we will convert its data type to datetime which is initially an object type.

df['reservation_status_date']=pd.to_datetime(df['reservation_status_date'],format="mixed")

# %%
df.describe(include='object') # to get a summary of all the object columns
#including object explicitly as the describe function by default gives stats of the columns with "NUMERICAL" values
# Out:
#              hotel arrival_date_month    meal country market_segment  \
# count       119390             119390  119390  118902         119390
# unique           2                 12       5     177              8
# top     City Hotel             August      BB     PRT      Online TA
# freq         79330              13877   92310   48590          56477
#
#        distribution_channel reserved_room_type assigned_room_type  \
# count                119390             119390             119390
# unique                    5                 10                 12
# top                   TA/TO                  A                  A
# freq                  97870              85994              74053
#
#        deposit_type customer_type reservation_status
# count        119390        119390             119390
# unique            3             4                  3
# top      No Deposit     Transient          Check-Out
# freq         104641         89613              75166

# %%
# to get all the unique categories for the columns of object data type

for col in df.describe(include='object').columns:
    print(col)
    print(df[col].unique())
    # first print the column name then its unique categories
    print('-'*50) #for clear look
# Out:
# hotel
# ['Resort Hotel' 'City Hotel']
# --------------------------------------------------
# arrival_date_month
# ['July' 'August' 'September' 'October' 'November' 'December' 'January'
#  'February' 'March' 'April' 'May' 'June']
# --------------------------------------------------
# meal
# ['BB' 'FB' 'HB' 'SC' 'Undefined']
# --------------------------------------------------
# country
# ['PRT' 'GBR' 'USA' 'ESP' 'IRL' 'FRA' nan 'ROU' 'NOR' 'OMN' 'ARG' 'POL'
#  'DEU' 'BEL' 'CHE' 'CN' 'GRC' 'ITA' 'NLD' 'DNK' 'RUS' 'SWE' 'AUS' 'EST'
#  'CZE' 'BRA' 'FIN' 'MOZ' 'BWA' 'LUX' 'SVN' 'ALB' 'IND' 'CHN' 'MEX' 'MAR'
#  'UKR' 'SMR' 'LVA' 'PRI' 'SRB' 'CHL' 'AUT' 'BLR' 'LTU' 'TUR' 'ZAF' 'AGO'
#  'ISR' 'CYM' 'ZMB' 'CPV' 'ZWE' 'DZA' 'KOR' 'CRI' 'HUN' 'ARE' 'TUN' 'JAM'
#  'HRV' 'HKG' 'IRN' 'GEO' 'AND' 'GIB' 'URY' 'JEY' 'CAF' 'CYP' 'COL' 'GGY'
#  'KWT' 'NGA' 'MDV' 'VEN' 'SVK' 'FJI' 'KAZ' 'PAK' 'IDN' 'LBN' 'PHL' 'SEN'
#  'SYC' 'AZE' 'BHR' 'NZL' 'THA' 'DOM' 'MKD' 'MYS' 'ARM' 'JPN' 'LKA' 'CUB'
# ...

# %%
# return column name and count of missing values in that column:-

df.isnull().sum()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %%
#since agent and company columns have so many missing values therefore we will remove those columns.Moreover these columns are not of significant use to the analysis that we are aiming for

df.drop(['company','agent'],axis=1,errors="ignore",inplace=True) # to remove agent and company columns
df.dropna(inplace=True)#to remove the missing values --to remove rows with missing values

# %%
df.isnull().sum() # now the dataset has no missing values
# Out:
# hotel                             0
# is_canceled                       0
# lead_time                         0
# arrival_date_year                 0
# arrival_date_month                0
# arrival_date_week_number          0
# arrival_date_day_of_month         0
# stays_in_weekend_nights           0
# stays_in_week_nights              0
# adults                            0
# children                          0
# babies                            0
# meal                              0
# country                           0
# market_segment                    0
# distribution_channel              0
# is_repeated_guest                 0
# previous_cancellations            0
# previous_bookings_not_canceled    0
# reserved_room_type                0
# assigned_room_type                0
# booking_changes                   0
# deposit_type                      0
# days_in_waiting_list              0
# customer_type                     0
# adr                               0
# ...

# %%
# summary statistics of the numerical columns: 

df.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  118898.000000  118898.000000      118898.000000
# mean        0.371352     104.311435        2016.157656
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     161.000000        2017.000000
# max         1.000000     737.000000        2017.000000
# std         0.483168     106.903309           0.707459
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             118898.000000              118898.000000
# mean                  27.166555                  15.800880
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# 75%                   38.000000                  23.000000
# ...

# %%
# removing relevant outliers like adr being -6 or 5400

df=df[df['adr']>0]
df=df[df['adr']<5400]

# %%
df.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  116958.000000  116958.000000      116958.000000
# mean        0.375767     105.376879        2016.161443
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      19.000000        2016.000000
# 50%         0.000000      71.000000        2016.000000
# 75%         1.000000     162.000000        2017.000000
# max         1.000000     709.000000        2017.000000
# std         0.484322     106.944356           0.706509
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             116958.000000              116958.000000
# mean                  27.138109                  15.805050
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   27.000000                  16.000000
# 75%                   38.000000                  23.000000
# ...

# %% [markdown]
# # Data Analysis and Visualisations:-

# %%
# 'value_counts' function-->>returns category name and how many times it is present in the column:- use "(normalize=True)" in  value_counts() for percentage

cancelled_perc=df['is_canceled'].value_counts(normalize=True)
cancelled_perc

#0--represents not cancelled
#1--represents cancelled
# Out:
# is_canceled
# 0    0.624233
# 1    0.375767
# Name: proportion, dtype: float64

# %%
# the above result implies that around 62% reservations are not cancelled and 37% of cancellations are cancelled

# %%
# visualising the above result via a bar plot

cancelled_perc=df['is_canceled'].value_counts(normalize=True)
print(cancelled_perc)

plt.figure(figsize=(5,4))#figsize(width,height)
plt.title('Reservation Status Count')
plt.bar(['Not Cancelled','Cancelled'],df['is_canceled'].value_counts(),edgecolor='k',width=0.7)
plt.show()
# Out:
# is_canceled
# 0    0.624233
# 1    0.375767
# Name: proportion, dtype: float64

# %%
# finding cancellation rates depending on hotels

plt.figure(figsize=(8,4))
ax1=sns.countplot(x='hotel',hue='is_canceled',data=df,palette='Blues')
plt.title('Reservation status in different hotels',size=20)
plt.xlabel('hotel')
plt.ylabel('number of reservations')
plt.legend(['not canceled','canceled'])
plt.show()

# %%
resort_hotel=df[df['hotel']=='Resort Hotel']
resort_hotel['is_canceled'].value_counts(normalize=True)
# Out:
# is_canceled
# 0    0.717039
# 1    0.282961
# Name: proportion, dtype: float64

# %%
city_hotel=df[df['hotel']=='City Hotel']
city_hotel['is_canceled'].value_counts(normalize=True)
# Out:
# is_canceled
# 0    0.578059
# 1    0.421941
# Name: proportion, dtype: float64

# %%
# above codes give cacnellation percentages of resort hotels and city hotels repectively

# %% [markdown]
# Effect of price on the cancellations:-

# %%
resort_hotel=resort_hotel.groupby('reservation_status_date')[['adr']].mean()
city_hotel=city_hotel.groupby('reservation_status_date')[['adr']].mean()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 resort_hotel=resort_hotel.groupby('reservation_status_date')[['adr']].mean()
#       2 city_hotel=city_hotel.groupby('reservation_status_date')[['adr']].mean()
#
# NameError: name 'resort_hotel' is not defined

# %%
plt.figure(figsize=(20,8))
plt.title('Average Daily Rate in City and Resort Hotel',fontsize=30)
plt.plot(resort_hotel.index,resort_hotel['adr'],label='Resort Hotel')
plt.plot(city_hotel.index,city_hotel['adr'],label='City Hotel')
plt.legend(fontsize=20)
plt.show()

# %%
# in whch month there are most cancellations or reservations:-

df['month']=df['reservation_status_date'].dt.month #extracting months from reservation status date
plt.figure(figsize=(16,8))
ax1=sns.countplot(x='month',hue='is_canceled',data=df)
plt.xlabel('Month')
plt.ylabel('Number of Reservations')
plt.legend(['not canceled','canceled'])
plt.show()

# %%
# cancellation: Highest=January;Lowest=August
#reservation: Highest=August;Lowest=January

# %%
plt.figure(figsize=(15,8))
plt.title('ADR per Month',fontsize=30)
sns.barplot(x='month',y='adr',data=df[df['is_canceled']==1].groupby('month')[['adr']].sum().reset_index())# month-wise avg daily rate ;'reset_index??--->>to take month column out from the index
plt.show()

# %%
# the above plot shows that the adr is lowest in august which corresponds to lowest cancellations in the same month and similarly adr being highest in month of January,the cancellations are higher in january.
#Hence this proves that Higher prices lead to increased cancellations

# %%
#country_wise

cancelled_data=df[df['is_canceled']==1]
top_10_country=cancelled_data['country'].value_counts()[:10]#this command gives only the corresponding top 10 values filtered acc to the code
plt.figure(figsize=(8,8))
plt.title('Top 10 countries with reservation canceled')
plt.pie(top_10_country,autopct='%.2f',labels=top_10_country.index)#autopct='%.2f' -->rounding off to decimal places
plt.show()
#figure shows portugal has highest no of cancellations

# %%
# to check from where more customers are coming from:(online bookings or offline agents)? 

df['market_segment'].value_counts()
# Out:
# market_segment
# Online TA        56036
# Offline TA/TO    23829
# Groups           19554
# Direct           12210
# Corporate         5035
# Aviation           231
# Complementary       63
# Name: count, dtype: int64

# %%
df['market_segment'].value_counts(normalize=True)
# Out:
# market_segment
# Online TA        0.479112
# Offline TA/TO    0.203740
# Groups           0.167188
# Direct           0.104396
# Corporate        0.043050
# Aviation         0.001975
# Complementary    0.000539
# Name: proportion, dtype: float64

# %%
cancelled_data['market_segment'].value_counts(normalize=True)
# Out:
# market_segment
# Online TA        0.471410
# Groups           0.274705
# Offline TA/TO    0.187467
# Direct           0.042982
# Corporate        0.022162
# Aviation         0.001160
# Complementary    0.000114
# Name: proportion, dtype: float64

# %%
#the above code implies that although 47% of the reservations are done online,all those reservations through online are being cancelled at the same time
#i.e., when reaching the hotel the customers are not satisfied by how the hotel actually is which might be contrary to what is being displayed online to lure the customers

# %%
# to check whose adr is high(cancelled reservations or not cancelled reservations)?

cancelled_df_adr=cancelled_data.groupby('reservation_status_date')[['adr']].mean()
cancelled_df_adr.reset_index(inplace=True)
cancelled_df_adr.sort_values('reservation_status_date',inplace=True)

not_cancelled_data=df[df['is_canceled']==0]
not_cancelled_df_adr=not_cancelled_data.groupby('reservation_status_date')[['adr']].mean()
not_cancelled_df_adr.reset_index(inplace=True)
not_cancelled_df_adr.sort_values('reservation_status_date',inplace=True)

plt.figure(figsize=(20,6))
plt.title('Average Daily Rate',fontsize=20)
plt.plot(not_cancelled_df_adr['reservation_status_date'],not_cancelled_df_adr['adr'],label='not_cancelled')
plt.plot(cancelled_df_adr['reservation_status_date'],cancelled_df_adr['adr'],label='cancelled')
plt.legend()

# %% [markdown]
# #NOTE- Index in a df is a series of labels that identify each row
# 'reset_index'-->>resets the index of the DataFrame and uses the default one instead
